# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("/home/jovyan/Salary.csv")

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %%
import matplotlib.pyplot as plt

# %%
X = data.iloc[:,:-1].values
Y = data.iloc[:,1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]])

# %%
Y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872, 127345, 126756,
#        128765, 135675, 139465])

# %%
plt.scatter(X,Y,color = "blue")

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.33,random_state = 0)

# %%
x_train
# Out:
# array([[12.3],
#        [ 9.5],
#        [11.2],
#        [ 3.2],
#        [ 4.1],
#        [ 2.9],
#        [ 5.3],
#        [ 4.5],
#        [11.5],
#        [ 8.7],
#        [ 1.3],
#        [ 4. ],
#        [ 3. ],
#        [ 8.2],
#        [ 2.2],
#        [ 5.9],
#        [ 7.1],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [12.9],
#        [ 2. ],
#        [ 1.1]])

# %%
y_train
# Out:
# array([128765, 116969, 127345,  64445,  57081,  56642,  83088,  61111,
#        126756, 109431,  46205,  56957,  60150, 113812,  39891,  81363,
#         98273,  93940,  57189,  54445, 135675,  43525,  39343])

# %%
y_test
# Out:
# array([121872,  91738,  66029, 122391, 101302,  67938,  63218,  37731,
#         55794, 112635, 105582, 139465])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([121240.47035944,  89080.02163531,  74303.59924855, 119502.06772571,
#         98641.23612087,  72565.19661482,  63873.18344613,  43012.35184129,
#         64742.384763  , 113417.65850763, 108202.45060642, 147316.50986549])

# %%
y_test
# Out:
# array([121872,  91738,  66029, 122391, 101302,  67938,  63218,  37731,
#         55794, 112635, 105582, 139465])

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="yellow")
plt.title("Salary VS Experience(Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="Red")
plt.plot(x_train,regressor.predict(x_train),color="yellow")
plt.title("Salary VS Experience(Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [8692.01316868]
# 29974.33208826927

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)                           #built-in function r2_score() indicates R-squared value 

print("RMSE =", rmse)
print("R2 Score=",r2)
# Out:
# RMSE = 4918.420049423368
# R2 Score= 0.9737903397670056
